# %%
# About this Dataset 
# https://open.canada.ca/data/en/dataset/bb9cc768-e2d5-4e1c-87dc-4ab6a38196b9
# http://www5.statcan.gc.ca/cansim/pick-choisir?lang=eng&id=01051101&p2=33#F2

# %%
library(dplyr)
library(data.table)
library(readr)
library(ggplot2)
library(ggthemes)
library(psych)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# Attaching package: ‘psych’
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha

# %%
df <- fread("https://raw.githubusercontent.com/tarjin/Canada_Open_Data/master/Mental_Health_CCHS_01051101-eng.csv")

# %%
glimpse(df)
# Out:
# Observations: 108,342
# Variables: 9
# $ Ref_Date   <int> 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 20...
# $ GEO        <chr> "Canada", "Canada", "Canada", "Canada", "Canada", "Canad...
# $ AGE        <chr> "Total, 15 years and over", "Total, 15 years and over", ...
# $ SEX        <chr> "Both sexes", "Both sexes", "Both sexes", "Both sexes", ...
# $ HRPROF     <chr> "Any selected disorder (mental or substance), life", "An...
# $ UNIT       <chr> "Number of persons", "Low 95% confidence interval, numbe...
# $ Vector     <chr> "v73982741", "v73982742", "v73982743", "v73982744", "v73...
# $ Coordinate <chr> "1.1.1.1.1", "1.1.1.1.2", "1.1.1.1.3", "1.1.1.1.4", "1.1...
# $ Value      <chr> "9124009.0", "8830159.0", "9417860.0", "1.6", "33.1", "3...

# %%
names(df) <- c("Year", "Geo", "Age_Group", "Sex", "Indicator", "Characteristic", "Vector", "Coordinate", "Value")

# %%
head(df)
# Out:
#   Year Geo    Age_Group                Sex
# 1 2012 Canada Total, 15 years and over Both sexes
# 2 2012 Canada Total, 15 years and over Both sexes
# 3 2012 Canada Total, 15 years and over Both sexes
# 4 2012 Canada Total, 15 years and over Both sexes
# 5 2012 Canada Total, 15 years and over Both sexes
# 6 2012 Canada Total, 15 years and over Both sexes
#   Indicator
# 1 Any selected disorder (mental or substance), life
# 2 Any selected disorder (mental or substance), life
# 3 Any selected disorder (mental or substance), life
# 4 Any selected disorder (mental or substance), life
# 5 Any selected disorder (mental or substance), life
# 6 Any selected disorder (mental or substance), life
#   Characteristic                                  Vector    Coordinate
# 1 Number of persons                               v73982741 1.1.1.1.1
# 2 Low 95% confidence interval, number of persons  v73982742 1.1.1.1.2
# 3 High 95% confidence interval, number of persons v73982743 1.1.1.1.3
# ...

# %%
tail(df)
# Out:
#   Year Geo              Age_Group         Sex
# 1 2012 British Columbia 65 years and over Females
# 2 2012 British Columbia 65 years and over Females
# 3 2012 British Columbia 65 years and over Females
# 4 2012 British Columbia 65 years and over Females
# 5 2012 British Columbia 65 years and over Females
# 6 2012 British Columbia 65 years and over Females
#   Indicator
# 1 Attention deficit disorder, current diagnosed condition
# 2 Attention deficit disorder, current diagnosed condition
# 3 Attention deficit disorder, current diagnosed condition
# 4 Attention deficit disorder, current diagnosed condition
# 5 Attention deficit disorder, current diagnosed condition
# 6 Attention deficit disorder, current diagnosed condition
#   Characteristic                                         Vector    Coordinate
# 1 Coefficient of variation for number of persons         v74035385 13.6.3.39.4
# 2 Percent                                                v74035386 13.6.3.39.5
# ...

# %%
df$Geo <- factor(df$Geo)

# %%
df$Age_Group <- factor(df$Age_Group)

# %%
df$Sex <- factor(df$Sex)

# %%
df$Indicator <- factor(df$Indicator)

# %%
df$Characteristic <- factor(df$Characteristic)

# %%
glimpse(df)
# Out:
# Observations: 108,342
# Variables: 9
# $ Year           <int> 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012...
# $ Geo            <fct> Canada, Canada, Canada, Canada, Canada, Canada, Cana...
# $ Age_Group      <fct> Total, 15 years and over, Total, 15 years and over, ...
# $ Sex            <fct> Both sexes, Both sexes, Both sexes, Both sexes, Both...
# $ Indicator      <fct> Any selected disorder (mental or substance), life, A...
# $ Characteristic <fct> Number of persons, Low 95% confidence interval, numb...
# $ Vector         <chr> "v73982741", "v73982742", "v73982743", "v73982744", ...
# $ Coordinate     <chr> "1.1.1.1.1", "1.1.1.1.2", "1.1.1.1.3", "1.1.1.1.4", ...
# $ Value          <chr> "9124009.0", "8830159.0", "9417860.0", "1.6", "33.1"...

# %%
describe(df) # from psych package
# Out:
# Warning message in describe(df):
# “NAs introduced by coercion”Warning message in describe(df):
# “NAs introduced by coercion”Warning message in describe(df):
# “NAs introduced by coercion”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to max; returning -Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to max; returning -Inf”
#                 vars n      mean         sd           median trimmed
# Year            1    108342   2009.58099 4.282364e+00 2012.0  2010.226227
# Geo*            2    108342      7.00000 3.741675e+00    7.0     7.000000
# Age_Group*      3    108342      3.50000 1.707833e+00    3.5     3.500000
# Sex*            4    108342      2.00000 8.165003e-01    2.0     2.000000
# ...

# %%
df_Suicidal_thoughts_12_months <- df %>%
  filter(Year == 2012) %>%
  filter(Characteristic == "Percent") %>%
  filter(Age_Group == "Total, 15 years and over") %>%
  filter(Sex %in% c("Females", "Males")) %>%
  filter(Geo %in% c("Newfoundland and Labrador", "Prince Edward Island", "Nova Scotia", 
                    "New Brunswick")) %>%
  filter(Indicator == "Suicidal thoughts, 12 months")

# %%
glimpse(df_Suicidal_thoughts_12_months)
# Out:
# Observations: 8
# Variables: 9
# $ Year           <int> 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012
# $ Geo            <fct> Newfoundland and Labrador, Newfoundland and Labrador...
# $ Age_Group      <fct> Total, 15 years and over, Total, 15 years and over, ...
# $ Sex            <fct> Males, Females, Males, Females, Males, Females, Male...
# $ Indicator      <fct> Suicidal thoughts, 12 months, Suicidal thoughts, 12 ...
# $ Characteristic <fct> Percent, Percent, Percent, Percent, Percent, Percent...
# $ Vector         <chr> "v73957968", "v73958094", "v73960236", "v73960362", ...
# $ Coordinate     <chr> "3.1.2.24.5", "3.1.3.24.5", "4.1.2.24.5", "4.1.3.24....
# $ Value          <chr> "2.2", "2.5", "F", "1.8", "4.9", "3.4", "2.7", "3.2"

# %%
df_Suicidal_thoughts_12_months$Value <- as.integer(df_Suicidal_thoughts_12_months$Value)
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”

# %%
glimpse(df_Suicidal_thoughts_12_months)
# Out:
# Observations: 8
# Variables: 9
# $ Year           <int> 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012
# $ Geo            <fct> Newfoundland and Labrador, Newfoundland and Labrador...
# $ Age_Group      <fct> Total, 15 years and over, Total, 15 years and over, ...
# $ Sex            <fct> Males, Females, Males, Females, Males, Females, Male...
# $ Indicator      <fct> Suicidal thoughts, 12 months, Suicidal thoughts, 12 ...
# $ Characteristic <fct> Percent, Percent, Percent, Percent, Percent, Percent...
# $ Vector         <chr> "v73957968", "v73958094", "v73960236", "v73960362", ...
# $ Coordinate     <chr> "3.1.2.24.5", "3.1.3.24.5", "4.1.2.24.5", "4.1.3.24....
# $ Value          <int> 2, 2, NA, 1, 4, 3, 2, 3

# %%
myplot <- ggplot(data = df_Suicidal_thoughts_12_months) +
  geom_col(aes(x = Geo, y = Value, fill = Sex)) +
  ylab("                Percent of Persons") +
  theme(axis.text.y = element_text(angle = 0, hjust = 0, size = 9)) +
  theme(axis.title.y = element_text(angle = 0, hjust = 0, size = 9)) +
  xlab(" ") +
  theme(axis.text.x = element_text(angle = 0, hjust = 0, size = 9)) +
  theme(axis.title.x = element_text(angle = 0, hjust = 0, size = 9)) +
  ggtitle("Percent of Persons with\nSuicidal Thoughts 2012\n(within last 12 months by Sex)\nfor Atlantic Provinces") +
  theme(plot.title = element_text(hjust = 0.5, size = 9)) +
  scale_y_continuous(labels=function(n){format(n, scientific = FALSE)}) +
  scale_fill_grey(start = 0, end = 0.5) +
  coord_flip()

# %%
myplot
# Out:
# Warning message:
# “Removed 1 rows containing missing values (position_stack).”

# %%
ggsave(width = 5, height = 2.5, filename = "Suicidal_thoughts_within_last_12_months_2012.png")
# Out:
# Warning message:
# “Removed 1 rows containing missing values (position_stack).”
