# %%
# About this Dataset 
# Lotto 649 winning numbers from inception to May 5, 2018 (N = 3573 draws)

# 31,40,46,47,48,49
# Total = 766 wins matching any two numbers as of May 5, 2018
# Total / Number of draws ~ 21.44%

# %%
library(dplyr)
library(data.table)
library(readr)
library(ggplot2)
library(ggthemes)
library(psych)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# Attaching package: ‘psych’
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha

# %%
df <- fread("https://raw.githubusercontent.com/tarjin/SpecialProjectsInR/master/Lotto649.csv")

# %%
glimpse(df)
# Out:
# Observations: 3,573
# Variables: 8
# $ DrawDate <chr> "Sat, May 5, 2018", "Wed, May 2, 2018", "Sat, Apr 28, 2018...
# $ First    <int> 4, 4, 24, 10, 12, 12, 1, 3, 18, 6, 3, 11, 9, 1, 16, 1, 2, ...
# $ Second   <int> 18, 7, 31, 14, 19, 17, 11, 7, 22, 8, 7, 12, 11, 5, 17, 9, ...
# $ Third    <int> 24, 28, 33, 15, 20, 19, 19, 10, 36, 9, 22, 19, 28, 9, 35, ...
# $ Fourth   <int> 26, 36, 34, 16, 30, 22, 36, 32, 40, 13, 26, 24, 30, 12, 43...
# $ Fifth    <int> 33, 37, 44, 40, 41, 27, 48, 41, 47, 34, 43, 28, 45, 39, 44...
# $ Sixth    <int> 48, 49, 46, 46, 49, 39, 49, 43, 49, 40, 47, 46, 49, 41, 46...
# $ Bonus    <int> 34, 21, 10, 6, 9, 38, 9, 33, 32, 4, 48, 39, 5, 28, 49, 21,...

# %%
glimpse(df)
# Out:
# Observations: 3,573
# Variables: 8
# $ DrawDate <chr> "Sat, May 5, 2018", "Wed, May 2, 2018", "Sat, Apr 28, 2018...
# $ First    <int> 4, 4, 24, 10, 12, 12, 1, 3, 18, 6, 3, 11, 9, 1, 16, 1, 2, ...
# $ Second   <int> 18, 7, 31, 14, 19, 17, 11, 7, 22, 8, 7, 12, 11, 5, 17, 9, ...
# $ Third    <int> 24, 28, 33, 15, 20, 19, 19, 10, 36, 9, 22, 19, 28, 9, 35, ...
# $ Fourth   <int> 26, 36, 34, 16, 30, 22, 36, 32, 40, 13, 26, 24, 30, 12, 43...
# $ Fifth    <int> 33, 37, 44, 40, 41, 27, 48, 41, 47, 34, 43, 28, 45, 39, 44...
# $ Sixth    <int> 48, 49, 46, 46, 49, 39, 49, 43, 49, 40, 47, 46, 49, 41, 46...
# $ Bonus    <int> 34, 21, 10, 6, 9, 38, 9, 33, 32, 4, 48, 39, 5, 28, 49, 21,...

# %%
plot(table(df$First))

# %%
plot(table(df$Second))

# %%
plot(table(df$Third))

# %%
plot(table(df$Fourth))

# %%
plot(table(df$Fifth))

# %%
plot(table(df$Sixth))

# %%
plot(table(df$Bonus))

# %%
df$N1 <- df$First == 1 # Set up dummy columns indicating if a number was drawn regardless of position

# %%
df$N2 <- df$First == 2 | df$Second == 2 | df$Third == 2 | df$Fourth == 2 | df$Fifth == 2 | df$Sixth == 2

# %%
df$N3 <- df$First == 3 | df$Second == 3 | df$Third == 3 | df$Fourth == 3 | df$Fifth == 3 | df$Sixth == 3

# %%
df$N4 <- df$First == 4 | df$Second == 4 | df$Third == 4 | df$Fourth == 4 | df$Fifth == 4 | df$Sixth == 4

# %%
df$N5 <- df$First == 5 | df$Second == 5 | df$Third == 5 | df$Fourth == 5 | df$Fifth == 5 | df$Sixth == 5

# %%
df$N6 <- df$First == 6 | df$Second == 6 | df$Third == 6 | df$Fourth == 6 | df$Fifth == 6 | df$Sixth == 6

# %%
df$N7 <- df$First == 7 | df$Second == 7 | df$Third == 7 | df$Fourth == 7 | df$Fifth == 7 | df$Sixth == 7

# %%
df$N8 <- df$First == 8 | df$Second == 8 | df$Third == 8 | df$Fourth == 8 | df$Fifth == 8 | df$Sixth == 8

# %%
df$N9 <- df$First == 9 | df$Second == 9 | df$Third == 9 | df$Fourth == 9 | df$Fifth == 9 | df$Sixth == 9

# %%
df$N10 <- df$First == 10 | df$Second == 10 | df$Third == 10 | df$Fourth == 10 | df$Fifth == 10 | df$Sixth == 10

# %%
df$N11 <- df$First == 11 | df$Second == 11 | df$Third == 11 | df$Fourth == 11 | df$Fifth == 11 | df$Sixth == 11

# %%
df$N12 <- df$First == 12 | df$Second == 12 | df$Third == 12 | df$Fourth == 12 | df$Fifth == 12 | df$Sixth == 12

# %%
df$N13 <- df$First == 13 | df$Second == 13 | df$Third == 13 | df$Fourth == 13 | df$Fifth == 13 | df$Sixth == 13

# %%
df$N14 <- df$First == 14 | df$Second == 14 | df$Third == 14 | df$Fourth == 14 | df$Fifth == 14 | df$Sixth == 14

# %%
df$N15 <- df$First == 15 | df$Second == 15 | df$Third == 15 | df$Fourth == 15 | df$Fifth == 15 | df$Sixth == 15

# %%
df$N16 <- df$First == 16 | df$Second == 16 | df$Third == 16 | df$Fourth == 16 | df$Fifth == 16 | df$Sixth == 16

# %%
df$N17 <- df$First == 17 | df$Second == 17 | df$Third == 17 | df$Fourth == 17 | df$Fifth == 17 | df$Sixth == 17

# %%
df$N18 <- df$First == 18 | df$Second == 18 | df$Third == 18 | df$Fourth == 18 | df$Fifth == 18 | df$Sixth == 18

# %%
df$N19 <- df$First == 19 | df$Second == 19 | df$Third == 19 | df$Fourth == 19 | df$Fifth == 19 | df$Sixth == 19

# %%
df$N20 <- df$First == 20 | df$Second == 20 | df$Third == 20 | df$Fourth == 20 | df$Fifth == 20 | df$Sixth == 20

# %%
df$N21 <- df$First == 21 | df$Second == 21 | df$Third == 21 | df$Fourth == 21 | df$Fifth == 21 | df$Sixth == 21

# %%
df$N22 <- df$First == 22 | df$Second == 22 | df$Third == 22 | df$Fourth == 22 | df$Fifth == 22 | df$Sixth == 22

# %%
df$N23 <- df$First == 23 | df$Second == 23 | df$Third == 23 | df$Fourth == 23 | df$Fifth == 23 | df$Sixth == 23

# %%
df$N24 <- df$First == 24 | df$Second == 24 | df$Third == 24 | df$Fourth == 24 | df$Fifth == 24 | df$Sixth == 24

# %%
df$N25 <- df$First == 25 | df$Second == 25 | df$Third == 25 | df$Fourth == 25 | df$Fifth == 25 | df$Sixth == 25

# %%
df$N26 <- df$First == 26 | df$Second == 26 | df$Third == 26 | df$Fourth == 26 | df$Fifth == 26 | df$Sixth == 26

# %%
df$N27 <- df$First == 27 | df$Second == 27 | df$Third == 27 | df$Fourth == 27 | df$Fifth == 27 | df$Sixth == 27

# %%
df$N28 <- df$First == 28 | df$Second == 28 | df$Third == 28 | df$Fourth == 28 | df$Fifth == 28 | df$Sixth == 28

# %%
df$N29 <- df$First == 29 | df$Second == 29 | df$Third == 29 | df$Fourth == 29 | df$Fifth == 29 | df$Sixth == 29

# %%
df$N30 <- df$First == 30 | df$Second == 30 | df$Third == 30 | df$Fourth == 30 | df$Fifth == 30 | df$Sixth == 30

# %%
df$N31 <- df$First == 31 | df$Second == 31 | df$Third == 31 | df$Fourth == 31 | df$Fifth == 31 | df$Sixth == 31

# %%
df$N32 <- df$First == 32 | df$Second == 32 | df$Third == 32 | df$Fourth == 32 | df$Fifth == 32 | df$Sixth == 32

# %%
df$N33 <- df$First == 33 | df$Second == 33 | df$Third == 33 | df$Fourth == 33 | df$Fifth == 33 | df$Sixth == 33

# %%
df$N34 <- df$First == 34 | df$Second == 34 | df$Third == 34 | df$Fourth == 34 | df$Fifth == 34 | df$Sixth == 34

# %%
df$N35 <- df$First == 35 | df$Second == 35 | df$Third == 35 | df$Fourth == 35 | df$Fifth == 35 | df$Sixth == 35

# %%
df$N36 <- df$First == 36 | df$Second == 36 | df$Third == 36 | df$Fourth == 36 | df$Fifth == 36 | df$Sixth == 36

# %%
df$N37 <- df$First == 37 | df$Second == 37 | df$Third == 37 | df$Fourth == 37 | df$Fifth == 37 | df$Sixth == 37

# %%
df$N38 <- df$First == 38 | df$Second == 38 | df$Third == 38 | df$Fourth == 38 | df$Fifth == 38 | df$Sixth == 38

# %%
df$N39 <- df$First == 39 | df$Second == 39 | df$Third == 39 | df$Fourth == 39 | df$Fifth == 39 | df$Sixth == 39

# %%
df$N40 <- df$First == 40 | df$Second == 40 | df$Third == 40 | df$Fourth == 40 | df$Fifth == 40 | df$Sixth == 40

# %%
df$N41 <- df$First == 41 | df$Second == 41 | df$Third == 41 | df$Fourth == 41 | df$Fifth == 41 | df$Sixth == 41

# %%
df$N42 <- df$First == 42 | df$Second == 42 | df$Third == 42 | df$Fourth == 42 | df$Fifth == 42 | df$Sixth == 42

# %%
df$N43 <- df$First == 43 | df$Second == 43 | df$Third == 43 | df$Fourth == 43 | df$Fifth == 43 | df$Sixth == 43

# %%
df$N44 <- df$First == 44 | df$Second == 44 | df$Third == 44 | df$Fourth == 44 | df$Fifth == 44 | df$Sixth == 44

# %%
df$N45 <- df$First == 45 | df$Second == 45 | df$Third == 45 | df$Fourth == 45 | df$Fifth == 45 | df$Sixth == 45

# %%
df$N46 <- df$First == 46 | df$Second == 46 | df$Third == 46 | df$Fourth == 46 | df$Fifth == 46 | df$Sixth == 46

# %%
df$N47 <- df$First == 47 | df$Second == 47 | df$Third == 47 | df$Fourth == 47 | df$Fifth == 47 | df$Sixth == 47

# %%
df$N48 <- df$Fifth == 48 | df$Sixth == 48

# %%
df$N49 <- df$Sixth == 49

# %%
df_query <- df %>% 
  filter(N31 == TRUE | N40 == TRUE | N46 == TRUE | N47 == TRUE | N48 == TRUE | N49 == TRUE)
count(df_query)
# Out:
#   n
# 1 2069

# %%
df_query1 <- df %>%
  filter(N31 == TRUE) %>%
  filter(N40 == TRUE)
count(df_query1)
# Out:
#   n
# 1 46

# %%
df_query2 <- df %>%
  filter(N31 == TRUE) %>%
  filter(N46 == TRUE)
count(df_query2)
# Out:
#   n
# 1 48

# %%
df_query3 <- df %>%
  filter(N31 == TRUE) %>%
  filter(N47 == TRUE)
count(df_query3)
# Out:
#   n
# 1 54

# %%
df_query4 <- df %>%
  filter(N31 == TRUE) %>%
  filter(N48 == TRUE)
count(df_query4)
# Out:
#   n
# 1 46

# %%
df_query5 <- df %>%
  filter(N31 == TRUE) %>%
  filter(N49 == TRUE)
count(df_query5)
# Out:
#   n
# 1 63

# %%
df_query6 <- df %>%
  filter(N40 == TRUE) %>%
  filter(N46 == TRUE)
count(df_query6)
# Out:
#   n
# 1 55

# %%
df_query7 <- df %>%
  filter(N40 == TRUE) %>%
  filter(N47 == TRUE)
count(df_query7)
# Out:
#   n
# 1 57

# %%
df_query8 <- df %>%
  filter(N40 == TRUE) %>%
  filter(N48 == TRUE)
count(df_query8)
# Out:
#   n
# 1 57

# %%
df_query9 <- df %>%
  filter(N40 == TRUE) %>%
  filter(N49 == TRUE)
count(df_query9)
# Out:
#   n
# 1 45

# %%
df_query10 <- df %>%
  filter(N46 == TRUE) %>%
  filter(N47 == TRUE)
count(df_query10)
# Out:
#   n
# 1 52

# %%
df_query11 <- df %>%
  filter(N46 == TRUE) %>%
  filter(N48 == TRUE)
count(df_query11)
# Out:
#   n
# 1 58

# %%
df_query12 <- df %>%
  filter(N46 == TRUE) %>%
  filter(N49 == TRUE)
count(df_query12)
# Out:
#   n
# 1 51

# %%
df_query13 <- df %>%
  filter(N47 == TRUE) %>%
  filter(N48 == TRUE)
count(df_query13)
# Out:
#   n
# 1 42

# %%
df_query14 <- df %>%
  filter(N47 == TRUE) %>%
  filter(N49 == TRUE)
count(df_query14)
# Out:
#   n
# 1 46

# %%
df_query15 <- df %>%
  filter(N48 == TRUE) %>%
  filter(N49 == TRUE)
count(df_query15)
# Out:
#   n
# 1 46

# %%
df_query_total <- rbind(df_query1, df_query2, df_query3, df_query4, df_query5,
                        df_query6, df_query7, df_query8, df_query9, df_query10,
                        df_query11, df_query12, df_query13, df_query14, df_query15)

# %%
glimpse(df_query_total)
# Out:
# Observations: 766
# Variables: 57
# $ DrawDate <chr> "Wed, Oct 25, 2017", "Wed, Oct 12, 2016", "Sat, Jun 13, 20...
# $ First    <int> 6, 8, 5, 23, 6, 11, 4, 4, 2, 11, 13, 2, 16, 10, 3, 20, 3, ...
# $ Second   <int> 31, 28, 8, 29, 29, 15, 6, 17, 31, 22, 14, 12, 21, 19, 21, ...
# $ Third    <int> 37, 31, 21, 31, 31, 16, 22, 20, 32, 31, 24, 31, 31, 25, 25...
# $ Fourth   <int> 40, 40, 31, 38, 33, 17, 24, 31, 34, 32, 31, 40, 40, 31, 26...
# $ Fifth    <int> 41, 42, 40, 40, 40, 31, 31, 36, 40, 40, 40, 44, 43, 37, 31...
# $ Sixth    <int> 42, 47, 45, 42, 43, 40, 40, 40, 49, 49, 48, 45, 45, 40, 40...
# $ Bonus    <int> 44, 37, 19, 44, 48, 6, 33, 37, 5, 13, 44, 11, 37, 1, 41, 1...
# $ N1       <lgl> FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FA...
# $ N2       <lgl> FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, TR...
# $ N3       <lgl> FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FA...
# ...

# %%
head(df_query_total)
# Out:
#   DrawDate          First Second Third Fourth Fifth Sixth Bonus N1    N2    ...
# 1 Wed, Oct 25, 2017  6    31     37    40     41    42    44    FALSE FALSE ...
# 2 Wed, Oct 12, 2016  8    28     31    40     42    47    37    FALSE FALSE ...
# 3 Sat, Jun 13, 2015  5     8     21    31     40    45    19    FALSE FALSE ...
# 4 Wed, Nov 5, 2014  23    29     31    38     40    42    44    FALSE FALSE ...
# 5 Sat, Mar 2, 2013   6    29     31    33     40    43    48    FALSE FALSE ...
# 6 Sat, Oct 27, 2012 11    15     16    17     31    40     6    FALSE FALSE ...
#   N40  N41   N42   N43   N44   N45   N46   N47   N48   N49
# 1 TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# 2 TRUE FALSE  TRUE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE
# 3 TRUE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE
# 4 TRUE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# 5 TRUE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %%
tail(df_query_total)
# Out:
#     DrawDate          First Second Third Fourth Fifth Sixth Bonus N1    N2
# 761 Sat, Oct 29, 1988  1    24     32    36     48    49    47     TRUE FALSE
# 762 Wed, Jul 30, 1986  3    26     39    44     48    49    13    FALSE FALSE
# 763 Sat, Apr 13, 1985  7    20     24    46     48    49    41    FALSE FALSE
# 764 Sat, Nov 17, 1984  8    35     44    46     48    49    22    FALSE FALSE
# 765 Sat, Oct 8, 1983  13    23     37    43     48    49    27    FALSE FALSE
# 766 Sat, Sep 17, 1983  9    21     22    29     48    49    28    FALSE FALSE
#     ... N40   N41   N42   N43   N44   N45   N46   N47   N48  N49
# 761 ... FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE TRUE TRUE
# 762 ... FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE TRUE TRUE
# 763 ... FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE TRUE TRUE
# 764 ... FALSE FALSE FALSE FALSE  TRUE FALSE  TRUE FALSE TRUE TRUE
# 765 ... FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE TRUE TRUE
# ...

# %%
df_query <- df %>% 
  filter(Sixth > 45)
count(df_query)
# Out:
#   n
# 1 1516

# %%
head(df_query)
# Out:
#   DrawDate          First Second Third Fourth Fifth Sixth Bonus N1    N2    ...
# 1 Sat, May 5, 2018   4    18     24    26     33    48    34    FALSE FALSE ...
# 2 Wed, May 2, 2018   4     7     28    36     37    49    21    FALSE FALSE ...
# 3 Sat, Apr 28, 2018 24    31     33    34     44    46    10    FALSE FALSE ...
# 4 Wed, Apr 25, 2018 10    14     15    16     40    46     6    FALSE FALSE ...
# 5 Sat, Apr 21, 2018 12    19     20    30     41    49     9    FALSE FALSE ...
# 6 Sat, Apr 14, 2018  1    11     19    36     48    49     9     TRUE FALSE ...
#   N40   N41   N42   N43   N44   N45   N46   N47   N48   N49
# 1 FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE
# 2 FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
# 3 FALSE FALSE FALSE FALSE  TRUE FALSE  TRUE FALSE FALSE FALSE
# 4  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE
# 5 FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
# ...

# %%
glimpse(df_query)
# Out:
# Observations: 1,516
# Variables: 57
# $ DrawDate <chr> "Sat, May 5, 2018", "Wed, May 2, 2018", "Sat, Apr 28, 2018...
# $ First    <int> 4, 4, 24, 10, 12, 1, 18, 3, 11, 9, 16, 2, 6, 3, 10, 18, 9,...
# $ Second   <int> 18, 7, 31, 14, 19, 11, 22, 7, 12, 11, 17, 10, 30, 14, 11, ...
# $ Third    <int> 24, 28, 33, 15, 20, 19, 36, 22, 19, 28, 35, 28, 33, 36, 24...
# $ Fourth   <int> 26, 36, 34, 16, 30, 36, 40, 26, 24, 30, 43, 43, 38, 38, 25...
# $ Fifth    <int> 33, 37, 44, 40, 41, 48, 47, 43, 28, 45, 44, 44, 45, 40, 30...
# $ Sixth    <int> 48, 49, 46, 46, 49, 49, 49, 47, 46, 49, 46, 48, 46, 48, 49...
# $ Bonus    <int> 34, 21, 10, 6, 9, 9, 32, 48, 39, 5, 49, 39, 40, 23, 47, 17...
# $ N1       <lgl> FALSE, FALSE, FALSE, FALSE, FALSE, TRUE, FALSE, FALSE, FAL...
# $ N2       <lgl> FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FA...
# $ N3       <lgl> FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, TRUE, FAL...
# ...

# %%
# 1,12 = 32            31,38 = 57           31,40 = 46          44,45 = 48        
# 1,22 = 39            31,46 = 48           31,46 = 48          44,46 = 35
# 1,31 = 50            31,47 = 54           31,47 = 54          44,47 = 49
# 1,38 = 44            31,48 = 46           31,48 = 46          44,48 = 40
# 1,49 = 45            31,49 = 63           31,49 = 63          44,49 = 44
# 12,22 = 47           38,46 = 54           40,46 = 55          45,46 = 56
# 12,31 = 43           38,47 = 53           40,47 = 57          45,47 = 49
# 12,38 = 48           38,48 = 39           40,48 = 57          45,48 = 46
# 12,49 = 49           38,49 = 34           40,49 = 45          45,49 = 48
# 22,31 = 41           46,47 = 52           46,47 = 52          46,47 = 52
# 22,38 = 48           46,48 = 58           46,48 = 58          46,48 = 58
# 22,49 = 49           46,49 = 51           46,49 = 51          46,49 = 51
# 31,38 = 57           47,48 = 42           47,48 = 42          47,48 = 42
# 31,49 = 63           47,49 = 46           47,49 = 46          47,49 = 46
# 38,49 = 34           48,49 = 46           48,49 = 46          48,49 = 46

# 1,12,22,31,38,49
# Total = 689 wins matching any two numbers as of May 5, 2018
# Total / Number of draws ~ 19.28%

# 31,38,46,47,48,49
# Total = 743 wins matching any two numbers as of May 5, 2018
# Total / Number of draws ~ 20.79%

# 31,40,46,47,48,49
# Total = 766 wins matching any two numbers as of May 5, 2018
# Total / Number of draws ~ 21.44%

# 44,45,46,47,48,49
# Total = 710 wins matching any two numbers as of May 5, 2018
# Total / Number of draws ~ 19.87%

# %%
glimpse(df)
# Out:
# Observations: 3,573
# Variables: 57
# $ DrawDate <chr> "Sat, May 5, 2018", "Wed, May 2, 2018", "Sat, Apr 28, 2018...
# $ First    <int> 4, 4, 24, 10, 12, 12, 1, 3, 18, 6, 3, 11, 9, 1, 16, 1, 2, ...
# $ Second   <int> 18, 7, 31, 14, 19, 17, 11, 7, 22, 8, 7, 12, 11, 5, 17, 9, ...
# $ Third    <int> 24, 28, 33, 15, 20, 19, 19, 10, 36, 9, 22, 19, 28, 9, 35, ...
# $ Fourth   <int> 26, 36, 34, 16, 30, 22, 36, 32, 40, 13, 26, 24, 30, 12, 43...
# $ Fifth    <int> 33, 37, 44, 40, 41, 27, 48, 41, 47, 34, 43, 28, 45, 39, 44...
# $ Sixth    <int> 48, 49, 46, 46, 49, 39, 49, 43, 49, 40, 47, 46, 49, 41, 46...
# $ Bonus    <int> 34, 21, 10, 6, 9, 38, 9, 33, 32, 4, 48, 39, 5, 28, 49, 21,...
# $ N1       <lgl> FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, TRUE, FALSE, FAL...
# $ N2       <lgl> FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FA...
# $ N3       <lgl> FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, TRUE, FAL...
# ...

# %%
head(df)
# Out:
#   DrawDate          First Second Third Fourth Fifth Sixth Bonus N1    N2    ...
# 1 Sat, May 5, 2018   4    18     24    26     33    48    34    FALSE FALSE ...
# 2 Wed, May 2, 2018   4     7     28    36     37    49    21    FALSE FALSE ...
# 3 Sat, Apr 28, 2018 24    31     33    34     44    46    10    FALSE FALSE ...
# 4 Wed, Apr 25, 2018 10    14     15    16     40    46     6    FALSE FALSE ...
# 5 Sat, Apr 21, 2018 12    19     20    30     41    49     9    FALSE FALSE ...
# 6 Wed, Apr 18, 2018 12    17     19    22     27    39    38    FALSE FALSE ...
#   N40   N41   N42   N43   N44   N45   N46   N47   N48   N49
# 1 FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE
# 2 FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
# 3 FALSE FALSE FALSE FALSE  TRUE FALSE  TRUE FALSE FALSE FALSE
# 4  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE
# 5 FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
# ...

# %%
tail(df)
# Out:
#   DrawDate          First Second Third Fourth Fifth Sixth Bonus N1    N2    ...
# 1 Sat, Jul 17, 1982 8     20     21    25     31    41    33    FALSE FALSE ...
# 2 Sat, Jul 10, 1982 5     14     21    31     34    47    45    FALSE FALSE ...
# 3 Sat, Jul 3, 1982  3      9     10    13     20    43    34    FALSE FALSE ...
# 4 Sat, Jun 26, 1982 1      6     23    24     27    39    34     TRUE FALSE ...
# 5 Sat, Jun 19, 1982 8     33     36    37     39    41     9    FALSE FALSE ...
# 6 Sat, Jun 12, 1982 3     11     12    14     41    43    13    FALSE FALSE ...
#   N40   N41   N42   N43   N44   N45   N46   N47   N48   N49
# 1 FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# 2 FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE
# 3 FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
# 4 FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# 5 FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %%
describe(df) # from psych package
# Out:
# Warning message in describe(df):
# “NAs introduced by coercion”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# “no non-missing arguments to min; returning Inf”Warning message in FUN(newX[, i], ...):
# ...

# %%
df_Sixth <- df %>% # How to obtain the mode value for this column
  count(Sixth, sort = TRUE)

# %%
df_Sixth
# Out:
#    Sixth n
# 1  49    440
# 2  47    381
# 3  48    379
# 4  46    316
# 5  45    301
# 6  44    257
# 7  43    227
# 8  42    193
# 9  41    155
# 10 40    152
# 11 39    123
# 12 38    104
# 13 37     84
# 14 36     83
# 15 35     75
# 16 33     52
# 17 34     45
# 18 32     38
# 19 31     37
# 20 29     27
# 21 30     23
# 22 28     20
# 23 27     18
# 24 26     12
# 25 23      7
# 26 25      6
# 27 20      4
# 28 21      4
# 29 24      4
# 30 19      3
# 31 13      1
# 32 18      1
# 33 22      1

# %%
df_Fifth <- df %>%
  count(Fifth, sort = TRUE)

# %%
df_Fifth
# Out:
#    Fifth n
# 1  38    205
# 2  41    200
# 3  40    199
# 4  43    186
# 5  37    184
# 6  34    183
# 7  39    179
# 8  42    176
# 9  35    163
# 10 36    161
# 11 44    156
# 12 45    154
# 13 33    140
# 14 31    135
# 15 46    135
# 16 32    126
# 17 30    115
# 18 27     94
# 19 29     87
# 20 28     82
# 21 47     80
# 22 24     63
# 23 26     62
# 24 25     54
# 25 48     46
# 26 23     39
# 27 22     36
# 28 21     33
# 29 20     27
# 30 19     23
# 31 17     14
# 32 18     10
# 33 14      8
# 34 13      6
# 35 16      5
# 36 12      3
# 37 11      2
# 38 15      2

# %%
df_Fourth <- df %>%
  count(Fourth, sort = TRUE)

# %%
df_Fourth
# Out:
#    Fourth n
# 1  31     197
# 2  27     169
# 3  34     165
# 4  33     161
# 5  32     158
# 6  26     157
# 7  30     155
# 8  28     152
# 9  29     145
# 10 36     136
# 11 25     134
# 12 23     128
# 13 35     125
# 14 37     121
# 15 24     115
# 16 38     115
# 17 20     107
# 18 22     107
# 19 39     103
# 20 40     102
# 21 21      95
# 22 19      81
# 23 18      78
# 24 41      77
# 25 42      58
# 26 16      57
# 27 17      57
# 28 15      46
# 29 43      46
# 30 14      36
# 31 44      27
# 32 11      26
# 33 12      25
# 34 13      23
# 35 45      21
# 36 10      19
# 37  9      15
# 38 46      13
# 39  8      11
# 40 47       4
# 41  7       3
# 42  4       2
# 43  6       1

# %%
df_Third <- df %>%
  count(Third, sort = TRUE)

# %%
df_Third
# Out:
#    Third n
# 1  22    174
# 2  23    166
# 3  19    162
# 4  20    158
# 5  21    158
# 6  25    158
# 7  24    156
# 8  17    148
# 9  18    148
# 10 16    136
# 11 26    131
# 12 15    126
# 13 29    125
# 14 27    121
# 15 28    111
# 16 14    110
# 17 13    109
# 18 12    102
# 19 30     98
# 20 31     93
# 21 32     90
# 22 11     89
# 23 33     80
# 24 10     74
# 25 34     67
# 26  9     66
# 27  8     57
# 28 36     56
# 29 35     51
# 30  7     50
# 31  6     40
# 32 37     36
# 33 38     28
# 34 40     26
# 35 39     19
# 36 41     17
# 37  5     15
# 38 42      6
# 39  4      5
# 40 43      5
# 41  3      3
# 42 44      2
# 43 45      1

# %%
df_Second <- df %>%
  count(Second, sort = TRUE)

# %%
df_Second
# Out:
#    Second n
# 1  12     188
# 2   8     183
# 3  10     181
# 4   7     176
# 5   9     175
# 6  13     172
# 7  15     172
# 8  14     166
# 9  11     159
# 10 17     158
# 11 16     154
# 12  5     150
# 13  6     149
# 14 20     132
# 15 19     128
# 16 18     125
# 17 21     120
# 18  4      97
# 19 22      93
# 20  3      90
# 21 23      82
# 22 24      80
# 23 26      63
# 24 25      60
# 25 27      48
# 26  2      46
# 27 29      45
# 28 28      42
# 29 30      39
# 30 32      25
# 31 31      21
# 32 33      13
# 33 34      11
# 34 35      11
# 35 36       4
# 36 37       4
# 37 39       3
# 38 40       3
# 39 38       2
# 40 41       1
# 41 42       1
# 42 43       1

# %%
df_First <- df %>%
  count(First, sort = TRUE)

# %%
df_First
# Out:
#    First n
# 1   1    415
# 2   2    382
# 3   3    342
# 4   4    342
# 5   5    254
# 6   6    226
# 7   7    222
# 8   9    190
# 9   8    182
# 10 10    149
# 11 11    139
# 12 12    122
# 13 13     99
# 14 14     67
# 15 15     67
# 16 16     67
# 17 17     52
# 18 18     51
# 19 20     41
# 20 19     37
# 21 21     28
# 22 23     26
# 23 22     17
# 24 24     12
# 25 26     11
# 26 27      9
# 27 25      6
# 28 28      5
# 29 29      4
# 30 30      4
# 31 31      2
# 32 32      1
# 33 33      1
# 34 38      1
